# %% [markdown]
# ### Superstore EDA project ##

# %% [markdown]
# **Importing liabrary**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import openpyxl

# %matplotlib inline

# %% [markdown]
# **Loading the dataset**

# %%
data = pd.read_csv('Superstore.csv',encoding_errors='ignore')

# %% [markdown]
# **Data Expolaration**

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.shape
# Out:
# (9994, 21)

# %%
data.info
# Out:
# <bound method DataFrame.info of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156  09-11-2013  12-11-2013    Second Class
# 1          2  CA-2013-152156  09-11-2013  12-11-2013    Second Class
# 2          3  CA-2013-138688  13-06-2013  17-06-2013    Second Class
# 3          4  US-2012-108966  11-10-2012  18-10-2012  Standard Class
# 4          5  US-2012-108966  11-10-2012  18-10-2012  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422  22-01-2011  24-01-2011    Second Class
# 9990    9991  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9991    9992  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9992    9993  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9993    9994  CA-2014-119914  05-05-2014  10-05-2014    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# **Data.Cleaning**

# %%
## Finding the missing value in the dataset

data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# Dealing with Duplicates rows

data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Data Analysis(EDA)**

# %% [markdown]
# **Calculate Summary Statistics for Numerical Columns**

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Summary statistics for numerical columns

summary_stats = data[['Sales', 'Quantity', 'Discount', 'Profit']].describe().loc[['mean', '50%', 'min', 'max', 'std']]
summary_stats.rename(index={'50%': 'median'},inplace ='True')
print(summary_stats)
# Out:
#                Sales   Quantity  Discount       Profit
# mean      229.858001   3.789574  0.156203    28.656896
# median     54.490000   3.000000  0.200000     8.666500
# min         0.444000   1.000000  0.000000 -6599.978000
# max     22638.480000  14.000000  0.800000  8399.976000
# std       623.245101   2.225110  0.206452   234.260108

# %%
# Unique value counts for categorical columns

unique_values = {
    'Segment': data['Segment'].nunique(),
    'Country': data['Country'].nunique(),
    'Region': data['Region'].nunique(),
    'Category': data['Category'].nunique(),
    'Sub-Category': data['Sub-Category'].nunique()
}
print(unique_values)
# Out:
# {'Segment': 3, 'Country': 1, 'Region': 4, 'Category': 3, 'Sub-Category': 17}

# %% [markdown]
# **Univariate Analysis Numerical Columns**

# %%
# Plot histograms for Sales, Profit, Quantity, and Discount

numerical_columns = ['Sales', 'Profit', 'Quantity', 'Discount']
data[numerical_columns].hist(bins=20, figsize=(12, 8), color='lightgreen')
plt.suptitle('Distribution of Sales, Profit, Quantity, and Discount')
plt.show()

# %% [markdown]
#  **Univariate Analysis**

# %%
# Plot boxplot for Sales, Profit, Quantity, and Discount

plt.figure(figsize=(12, 8))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(data[column], color='lightgreen')
    plt.title(f'Box Plot of {column}')
plt.suptitle('Box Plots for Sales, Profit, Quantity, and Discount')
plt.tight_layout()
plt.show()

# %%
# Bar charts display the frequency distribution of categorical variables, making it easy to see the counts for each category.


categorical_columns = ['Segment', 'Category', 'Sub-Category', 'Ship Mode', 'Region']
plt.figure(figsize=(14, 10))
for i, column in enumerate(categorical_columns, 1):
    plt.subplot(3, 2, i)
    sns.countplot(y=data[column], palette='viridis')
    plt.title(f'Frequency Distribution of {column}')
    plt.xlabel('Count')
plt.suptitle('Bar Charts for Segment, Category, Sub-Category, Ship Mode, and Region')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\viraj\AppData\Local\Temp\ipykernel_22768\1155282092.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=data[column], palette='viridis')
# C:\Users\viraj\AppData\Local\Temp\ipykernel_22768\1155282092.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=data[column], palette='viridis')
# C:\Users\viraj\AppData\Local\Temp\ipykernel_22768\1155282092.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=data[column], palette='viridis')
# ...

# %% [markdown]
# **Bivariate Analysis**

# %%
# creating a scatter plot  for Sales and Profit Analysis

plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Sales', y='Profit',color=('green'))
plt.title('Sales vs. Profit Analysis')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
## Scatter plot of Discount vs. Profit


plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Discount', y='Profit',color='green')
plt.title('Discount vs. Profit Analysis')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %%
# Box Plot for Sales by Category

plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Category', y='Sales')
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
# Box Plot for Profit by Category

plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Category', y='Profit',color=('green'))
plt.title('Profit by Category')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.show()

# %%
# Group by Sub-Category and calculate mean for  Sales and Profit

sub_category_means = data.groupby('Sub-Category')[['Sales', 'Profit']].mean().reset_index()

# %%
# Plotting
plt.figure(figsize=(15, 8))
sns.barplot(data=sub_category_means, x='Sub-Category', y='Sales', color='lightgreen', label='Sales')
sns.barplot(data=sub_category_means, x='Sub-Category', y='Profit', color='darkgreen', label='Profit')
plt.title('Average Sales and Profit by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Amount')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# **Time-Series Analysis**

# %%
# Convert 'Order Date' and 'Ship Date' to datetime format


data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
# Extract month and year from 'Order Date' for grouping
data['YearMonth'] = data['Order Date'].dt.to_period('M')

# Group by 'YearMonth' and calculate total sales for each month
monthly_sales = data.groupby('YearMonth')['Sales'].sum()

# Plot monthly sales trend
plt.figure(figsize=(12, 6))
monthly_sales.plot(kind='line', marker='o',color=('green'))
plt.title('Monthly Sales Trend')
plt.xlabel('Year-Month')
plt.ylabel('Total Sales')
plt.grid()
plt.show()

# %%
# Calculate shipping time in days
data['Shipping Time'] = (data['Ship Date'] - data['Order Date']).dt.days

# Plot the distribution of shipping time
plt.figure(figsize=(10, 5))
data['Shipping Time'].plot(kind='hist', bins=20, edgecolor='black',color='lightgreen')
plt.title('Shipping Time Distribution')
plt.xlabel('Shipping Time (Days)')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# **Segment Analysis**

# %%
# Barplot for comparing the sales with the segments 

plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='Segment', y='Sales', palette='Greens')
plt.title('Total Sales by Segment')
plt.xlabel('Segment')
plt.ylabel('Sales')
plt.show()
# Out:
# C:\Users\viraj\AppData\Local\Temp\ipykernel_22768\1307686320.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='Segment', y='Sales', palette='Greens')

# %%
# Barplot for comparing the profit  with the segments 


plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='Segment', y='Profit', palette='Greens')
plt.title('Total Profit by Segment')
plt.xlabel('Segment')
plt.ylabel('Profit')
plt.show()
# Out:
# C:\Users\viraj\AppData\Local\Temp\ipykernel_22768\1711387158.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='Segment', y='Profit', palette='Greens')

# %% [markdown]
# **Identifying Top Customers**

# %%
customer_sales_profit = data.groupby('Customer ID').agg({
    'Sales': 'sum',
    'Profit': 'sum'
}).reset_index()

# %%
top_customers = customer_sales_profit.sort_values(by='Sales', ascending=False).head(5)  # top 5 customers
print(top_customers)
# Out:
#     Customer ID      Sales     Profit
# 700    SM-20320  25043.050 -1980.7393
# 741    TC-20980  19052.218  8981.3239
# 621    RB-19360  15117.339  6976.0959
# 730    TA-21385  14595.620  4703.7883
# 6      AB-10105  14473.571  5444.8055

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Customer ID', y='Sales', data=top_customers,palette='Greens')
plt.title('Top Customers by Sales')
plt.show()
# Out:
# C:\Users\viraj\AppData\Local\Temp\ipykernel_22768\1206195224.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Customer ID', y='Sales', data=top_customers,palette='Greens')
